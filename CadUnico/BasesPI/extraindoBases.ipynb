# %%
import pandas as pd

# %%
cadunico_2012 = pd.read_csv("../BasesCompletas/base_amostra_familia_201212_20190131.csv", sep = ";", low_memory=False)
cadunico_2013 = pd.read_csv("../BasesCompletas/base_amostra_familia_201312_20190131.csv", sep = ";", low_memory=False)
cadunico_2014 = pd.read_csv("../BasesCompletas/base_amostra_familia_201412_20190131.csv", sep = ";", low_memory=False)
cadunico_2015 = pd.read_csv("../BasesCompletas/base_amostra_familia_201512_20190131.csv", sep = ";", low_memory=False)
cadunico_2016 = pd.read_csv("../BasesCompletas/base_amostra_familia_201612_20190131.csv", sep = ";", low_memory=False)
cadunico_2017 = pd.read_csv("../BasesCompletas/base_amostra_familia_201712_20190131.csv", sep = ";", low_memory=False)
cadunico_2018 = pd.read_csv("../BasesCompletas/base_amostra_familia_201812.csv", sep = ";", low_memory=False)

# %% [markdown]
# ## Base PI/2012

# %%
cadunico_pi_2012 = cadunico_2012[
    cadunico_2012['cd_ibge'].astype(str).str.startswith('22')
]

cadunico_pi_2012.head()
# Out:
#       cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 816   2202729        1       3     4533964            2001-11-19
# 4091  2206506        1       3     4448870            2001-11-29
# 4092  2206506        1       3     2126512            2001-11-29
# 4093  2206506        1       3     4448891            2001-11-29
# 4094  2206506        1       3     2126528            2001-11-29
#
#      dat_alteracao_fam  vlr_renda_media_fam  cod_local_domic_fam  \
# 816         2011-10-25                  109                  2.0
# 4091        2012-12-13                  323                  2.0
# 4092        2011-10-28                    3                  2.0
# 4093        2012-04-03                   20                  2.0
# 4094        2012-09-24                    0                  2.0
#
#       cod_especie_domic_fam  qtd_comodos_domic_fam  ...  \
# 816                     1.0                    5.0  ...
# 4091                    1.0                    6.0  ...
# ...

# %%
cadunico_pi_2012.to_csv('BasesAno/cadunico_pi_2012.csv', index=False, sep=';')

# %% [markdown]
# ## Base PI/2013

# %%
cadunico_pi_2013 = cadunico_2013[
    cadunico_2013['cd_ibge'].astype(str).str.startswith('22')
]

cadunico_pi_2013.head()
# Out:
#       cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 3984  2206506        1       3     4869816            2001-11-29
# 3985  2206506        1       3     2337860            2001-11-29
# 3986  2206506        1       3     2337861            2001-11-29
# 3987  2206506        1       3     2337888            2001-11-29
# 3988  2204303        1       3     4838764            2001-11-30
#
#      dat_alteracao_fam  vlr_renda_media_fam  cod_local_domic_fam  \
# 3984        2012-12-13                  323                  2.0
# 3985        2012-11-19                   20                  2.0
# 3986        2013-10-29                    6                  2.0
# 3987        2012-10-30                   12                  1.0
# 3988        2013-06-17                  207                  1.0
#
#       cod_especie_domic_fam  qtd_comodos_domic_fam  ...  \
# 3984                    1.0                    6.0  ...
# 3985                    1.0                    4.0  ...
# ...

# %%
cadunico_pi_2013.to_csv('BasesAno/cadunico_pi_2013.csv', index=False, sep=';')

# %% [markdown]
# ## Base PI/2014

# %%
cadunico_pi_2014 = cadunico_2014[
    cadunico_2014['cd_ibge'].astype(str).str.startswith('22')
]

cadunico_pi_2014.head()
# Out:
#       cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 3759  2206506        1       3      865319            2001-11-29
# 3760  2206506        1       3     3615449            2001-11-29
# 3761  2204303        1       3     2750748            2001-11-30
# 3762  2204303        1       3        1452            2001-11-30
# 3763  2206506        1       3     3615441            2001-11-30
#
#      dat_alteracao_fam vlr_renda_media_fam  cod_local_domic_fam  \
# 3759        2014-05-21                  27                  1.0
# 3760        2012-01-27                   0                  2.0
# 3761        2012-07-18                   7                  1.0
# 3762        2012-08-09                  50                  1.0
# 3763        2014-11-26                  17                  2.0
#
#       cod_especie_domic_fam  qtd_comodos_domic_fam  ...  \
# 3759                    1.0                    5.0  ...
# 3760                    1.0                    4.0  ...
# ...

# %%
cadunico_pi_2014.to_csv('BasesAno/cadunico_pi_2014.csv', index=False, sep=';')

# %% [markdown]
# ## Base PI/2015

# %%
cadunico_pi_2015 = cadunico_2015[
    cadunico_2015['cd_ibge'].astype(str).str.startswith('22')
]

cadunico_pi_2015.head()
# Out:
#      cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 81   2211001        2       1          82            2012-07-30
# 95   2204659        1       3          96            2003-03-13
# 107  2201929        1       3         108            2006-09-27
# 119  2204659        1       3         120            2002-12-17
# 133  2211001        2       1         134            2008-05-07
#
#     dat_alteracao_fam vlr_renda_media_fam dat_atualizacao_familia  \
# 81         2012-07-30                 175              2012-07-30
# 95         2015-02-06                 181              2015-02-06
# 107        2015-06-11                   2              2015-06-11
# 119        2015-11-04                  20              2015-11-04
# 133        2014-09-23                  44              2014-09-23
#
#      cod_local_domic_fam  cod_especie_domic_fam  ...  \
# 81                   1.0                    1.0  ...
# 95                   1.0                    1.0  ...
# ...

# %%
cadunico_pi_2015.to_csv('BasesAno/cadunico_pi_2015.csv', index=False, sep=';')

# %% [markdown]
# ## Base PI/2016

# %%
cadunico_pi_2016 = cadunico_2016[
    cadunico_2016['cd_ibge'].astype(str).str.startswith('22')
]

cadunico_pi_2016.head()
# Out:
#       cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 7537  2201606        1       2        9334            2007-10-10
# 7538  2201606        1       2        9335            2003-03-13
# 7539  2203305        1       2        9338            2016-08-10
# 7540  2205557        1       2        9339            2002-08-21
# 7541  2202737        1       2        9340            2008-05-30
#
#      dat_alteracao_fam vlr_renda_media_fam dat_atualizacao_familia  \
# 7537        2015-06-01                   0              2015-06-01
# 7538        2016-11-17                   0              2016-08-29
# 7539        2016-08-10                  20              2016-08-10
# 7540        2016-10-15                  30              2016-10-14
# 7541        2015-04-22                 315              2015-04-22
#
#       cod_local_domic_fam  cod_especie_domic_fam  ...  \
# 7537                  2.0                    1.0  ...
# 7538                  2.0                    1.0  ...
# ...

# %%
cadunico_pi_2016.to_csv('BasesAno/cadunico_pi_2016.csv', index=False, sep=';')

# %% [markdown]
# ## Base PI/2017

# %%
cadunico_pi_2017 = cadunico_2017[
    cadunico_2017['cd_ibge'].astype(str).str.startswith('22')
]

cadunico_pi_2017.head()
# Out:
#      cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 45   2209708        1       3          46            2006-06-17
# 121  2201507        2       3         123            2011-07-08
# 135  2211001        2       1         137            2016-01-13
# 155  2207702        2       3         157            2017-05-15
# 161  2202208        2       3         163            2013-07-22
#
#     dat_alteracao_fam vlr_renda_media_fam dat_atualizacao_familia  \
# 45         2017-03-30                   3              2017-03-29
# 121        2015-09-28                   1              2015-09-28
# 135        2017-09-20                   1              2017-09-19
# 155        2017-05-17                 425              2017-05-15
# 161        2017-10-10                 937              2017-10-09
#
#      cod_local_domic_fam  cod_especie_domic_fam  ...  \
# 45                   2.0                    1.0  ...
# 121                  2.0                    1.0  ...
# ...

# %%
cadunico_pi_2017.to_csv('BasesAno/cadunico_pi_2017.csv', index=False, sep=';')

# %% [markdown]
# ## Base PI/2018

# %%
cadunico_pi_2018 = cadunico_2018[
    cadunico_2018['cd_ibge'].astype(str).str.startswith('22')
]

cadunico_pi_2018.head()
# Out:
#        cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 13325  2211100        2       2     16733.0            2005-09-09
# 13326  2201606        1       2     16734.0            2006-05-26
# 13327  2205508        2       2     16735.0            2016-12-15
# 13328  2205508        2       2     16736.0            2007-02-15
# 13329  2200400        2       2     16737.0            2003-03-13
#
#       dat_alteracao_fam  vlr_renda_media_fam dat_atualizacao_familia  \
# 13325        2016-05-18                  0.0              2016-05-18
# 13326        2018-09-30                 20.0              2017-09-21
# 13327        2018-10-01                311.0              2017-01-31
# 13328        2018-11-29                  0.0              2018-11-29
# 13329        2018-09-30                115.0              2017-11-08
#
#        cod_local_domic_fam  cod_especie_domic_fam  ...  \
# 13325                  1.0                    1.0  ...
# ...

# %%
cadunico_pi_2018.to_csv('BasesAno/cadunico_pi_2018.csv', index=False, sep=';')

# %% [markdown]
# ## Mesclando os dados

# %%
# Adiciona a coluna ano em cada base
for ano, df in [
    (2012, cadunico_2012),
    (2013, cadunico_2013),
    (2014, cadunico_2014),
    (2015, cadunico_2015),
    (2016, cadunico_2016),
    (2017, cadunico_2017),
    (2018, cadunico_2018),
]:
    df["ano"] = ano

# %%
# Mesclando os arquivos CSV em um único DataFrame
cadunico_combined = pd.concat([cadunico_2012, cadunico_2013, cadunico_2014,
                              cadunico_2015, cadunico_2016, cadunico_2017, cadunico_2018],
                              ignore_index=True)

# %%
# Filtrando os dados apenas para os municípios do RN
cadunico_pi_combined = cadunico_combined[cadunico_combined['cd_ibge'].astype(str).str.startswith('22')]

# Salvando o arquivo filtrado
cadunico_pi_combined.to_csv('cadunico_pi_combined.csv', index=False, sep=';')
