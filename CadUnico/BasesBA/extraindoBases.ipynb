# %%
import pandas as pd

# %%
cadUnico_2012 = pd.read_csv('../BasesCompletas/base_amostra_familia_201212_20190131.csv', sep=';', low_memory=False)
cadUnico_2013 = pd.read_csv('../BasesCompletas/base_amostra_familia_201312_20190131.csv', sep=';', low_memory=False)
cadUnico_2014 = pd.read_csv('../BasesCompletas/base_amostra_familia_201412_20190131.csv', sep=';', low_memory=False)
cadUnico_2015 = pd.read_csv('../BasesCompletas/base_amostra_familia_201512_20190131.csv', sep=';', low_memory=False)
cadUnico_2016 = pd.read_csv('../BasesCompletas/base_amostra_familia_201612_20190131.csv', sep=';', low_memory=False)
cadUnico_2017 = pd.read_csv('../BasesCompletas/base_amostra_familia_201712_20190131.csv', sep=';', low_memory=False)
cadUnico_2018 = pd.read_csv('../BasesCompletas/base_amostra_familia_201812.csv', sep=';', low_memory=False)

# %% [markdown]
# ### Base BA/2012

# %%
cadunico_ba_2012 = cadUnico_2012[
    cadUnico_2012['cd_ibge'].astype(str).str.startswith('29')
]

cadunico_ba_2012.head()
# Out:
#      cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 817  2924009        2       3      746032            2001-11-19
# 818  2924009        2       3     3068318            2001-11-19
# 819  2924009        2       3      746033            2001-11-19
# 820  2924009        2       3      746049            2001-11-19
# 821  2924009        2       3      746050            2001-11-19
#
#     dat_alteracao_fam  vlr_renda_media_fam  cod_local_domic_fam  \
# 817        2012-12-05                    3                  2.0
# 818        2011-06-28                    0                  2.0
# 819        2011-05-03                  136                  2.0
# 820        2012-02-17                   50                  1.0
# 821        2012-04-25                   19                  2.0
#
#      cod_especie_domic_fam  qtd_comodos_domic_fam  ...  \
# 817                    1.0                    7.0  ...
# 818                    1.0                    5.0  ...
# ...

# %%
cadunico_ba_2012.to_csv('BasesAno/cadunico_ba_2012.csv', index=False, sep=';')

# %% [markdown]
# ### Base BA/2013

# %%
cadunico_ba_2013 = cadUnico_2013[
    cadUnico_2013['cd_ibge'].astype(str).str.startswith('29')
]

cadunico_ba_2013.head()
# Out:
#      cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 840  2924009        2       3      843539            2001-11-19
# 841  2924009        2       3      843557            2001-11-19
# 842  2924009        2       3     3373425            2001-11-19
# 843  2924009        2       3     3373428            2001-11-19
# 844  2924009        2       3     3373491            2001-11-19
#
#     dat_alteracao_fam  vlr_renda_media_fam  cod_local_domic_fam  \
# 840        2011-05-03                  136                  2.0
# 841        2013-09-06                  400                  2.0
# 842        2013-01-10                    4                  2.0
# 843        2012-11-23                    4                  2.0
# 844        2013-06-10                   25                  1.0
#
#      cod_especie_domic_fam  qtd_comodos_domic_fam  ...  \
# 840                    1.0                    5.0  ...
# 841                    1.0                    5.0  ...
# ...

# %%
cadunico_ba_2013.to_csv('BasesAno/cadunico_ba_2013.csv', index=False, sep=';')

# %% [markdown]
# ### Base BA/2014

# %%
cadunico_ba_2014 = cadUnico_2014[
    cadUnico_2014['cd_ibge'].astype(str).str.startswith('29')
]

cadunico_ba_2014.head()
# Out:
#      cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 754  2924009        2       3     3828693            2001-11-19
# 755  2924009        2       3     3828662            2001-11-19
# 756  2924009        2       3     3828679            2001-11-19
# 757  2924009        2       3     1078914            2001-11-19
# 758  2924009        2       3     1078906            2001-11-19
#
#     dat_alteracao_fam vlr_renda_media_fam  cod_local_domic_fam  \
# 754        2014-12-11                 144                  2.0
# 755        2013-05-08                   5                  1.0
# 756        2012-11-30                   3                  2.0
# 757        2014-10-08                  79                  1.0
# 758        2014-12-09                  13                  2.0
#
#      cod_especie_domic_fam  qtd_comodos_domic_fam  ...  \
# 754                    1.0                    6.0  ...
# 755                    1.0                    5.0  ...
# ...

# %%
cadunico_ba_2014.to_csv('BasesAno/cadunico_ba_2014.csv', index=False, sep=';')

# %% [markdown]
# ### Base BA/2015

# %%
cadunico_ba_2015 = cadUnico_2015[
    cadUnico_2015['cd_ibge'].astype(str).str.startswith('29')
]

cadunico_ba_2015.head()
# Out:
#     cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 1   2919207        2       2           2            2015-07-29
# 2   2910727        2       3           3            2002-06-13
# 9   2903201        2       3          10            2012-03-23
# 11  2902906        2       3          12            2002-05-16
# 35  2911709        2       3          36            2012-07-17
#
#    dat_alteracao_fam vlr_renda_media_fam dat_atualizacao_familia  \
# 1         2015-08-12                  75              2015-08-12
# 2         2014-11-24                 100              2014-11-24
# 9         2013-10-17                 370              2012-08-01
# 11        2014-07-01                  11              2014-05-06
# 35        2015-02-12                   0              2015-02-12
#
#     cod_local_domic_fam  cod_especie_domic_fam  ...  cod_familia_indigena_fam  \
# 1                   1.0                    1.0  ...                       2.0
# ...

# %%
cadunico_ba_2015.to_csv('BasesAno/cadunico_ba_2015.csv', index=False, sep=';')

# %% [markdown]
# ### Base BA/2016

# %%
cadunico_ba_2016 = cadUnico_2016[
    cadUnico_2016['cd_ibge'].astype(str).str.startswith('29')
]

cadunico_ba_2016.head()
# Out:
#       cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 3182  2919207        2       2        3953            2016-04-13
# 3183  2918407        2       2        3954            2010-06-18
# 3184  2918407        2       2        3955            2004-04-02
# 3185  2919207        2       2        3956            2004-09-10
# 3186  2921005        2       2        3957            2002-06-22
#
#      dat_alteracao_fam vlr_renda_media_fam dat_atualizacao_familia  \
# 3182        2016-04-13                   0              2016-04-13
# 3183        2015-03-10                  35              2015-03-10
# 3184        2015-04-09                  93              2015-04-09
# 3185        2013-04-05                 170              2013-04-05
# 3186        2016-11-30                 180              2016-11-29
#
#       cod_local_domic_fam  cod_especie_domic_fam  ...  \
# 3182                  1.0                    1.0  ...
# 3183                  1.0                    1.0  ...
# ...

# %%
cadunico_ba_2016.to_csv('BasesAno/cadunico_ba_2016.csv', index=False, sep=';')

# %% [markdown]
# ### Base BA/2017

# %%
cadunico_ba_2017 = cadUnico_2017[
    cadUnico_2017['cd_ibge'].astype(str).str.startswith('29')
]

cadunico_ba_2017.head()
# Out:
#     cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 14  2924009        2       3          15            2013-10-23
# 41  2905602        2       3          42            2012-07-13
# 60  2903409        2       3          61            2002-11-15
# 61  2915601        2       3          62            2009-01-30
# 74  2927408        2       1          75            2014-11-13
#
#    dat_alteracao_fam vlr_renda_media_fam dat_atualizacao_familia  \
# 14        2017-07-22                   6              2017-07-21
# 41        2017-11-02                 788              2015-12-21
# 60        2015-06-25                  73              2015-06-25
# 61        2017-05-05                  28              2017-05-04
# 74        2014-11-13                   6              2014-11-13
#
#     cod_local_domic_fam  cod_especie_domic_fam  ...  cod_familia_indigena_fam  \
# 14                  1.0                    1.0  ...                       2.0
# ...

# %%
cadunico_ba_2017.to_csv('BasesAno/cadunico_ba_2017.csv', index=False, sep=';')

# %% [markdown]
# ### Base BA/2018

# %%
cadunico_ba_2018 = cadUnico_2018[
    cadUnico_2018['cd_ibge'].astype(str).str.startswith('29')
]

cadunico_ba_2018.head()
# Out:
#      cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 383  2918407        2       2       499.0            2017-01-04
# 384  2910057        2       2       500.0            2003-02-18
# 385  2905701        2       2       501.0            2006-06-03
# 386  2918407        2       2       502.0            2011-07-18
# 387  2905701        2       2       503.0            2012-01-31
#
#     dat_alteracao_fam  vlr_renda_media_fam dat_atualizacao_familia  \
# 383        2018-09-26                122.0              2018-09-26
# 384        2018-09-30                 80.0              2018-06-07
# 385        2018-09-30                312.0              2017-11-22
# 386        2018-09-30                197.0              2015-09-18
# 387        2018-10-01                 12.0              2016-08-31
#
#      cod_local_domic_fam  cod_especie_domic_fam  ...  \
# 383                  1.0                    1.0  ...
# 384                  1.0                    1.0  ...
# ...

# %%
cadunico_ba_2018.to_csv('BasesAno/cadunico_ba_2018.csv', index=False, sep=';')

# %% [markdown]
# ### Mesclando os dados

# %%
# Mesclando os arquivos CSV em um único DataFrame
cadunico_combined = pd.concat([cadUnico_2012, cadUnico_2013, cadUnico_2014, 
                              cadUnico_2015, cadUnico_2016, cadUnico_2017, cadUnico_2018], 
                              ignore_index=True)

# %%
# Filtrando os dados apenas para os municípios do RN
cadunico_ba_combined = cadunico_combined[cadunico_combined['cd_ibge'].astype(str).str.startswith('29')]

# Salvando o arquivo filtrado
cadunico_ba_combined.to_csv('cadunico_ba_combined.csv', index=False, sep=';')
