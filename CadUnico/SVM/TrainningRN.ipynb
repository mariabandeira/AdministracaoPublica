# %% [markdown]
# # Treinando para dados do RN

# %% [markdown]
# ### Recuperando os dados

# %%
import pandas as pd

FILE_PATH = '../BasesRN/cadunico_rn_2018.csv'
cadUnicoRN = pd.read_csv(FILE_PATH, sep=';', low_memory=False)

# %% [markdown]
# ### Entendendo a estrutura os dados

# %%
cadUnicoRN.head()
# Out:
#    cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 0  2414803        1       2      3022.0            2017-12-04
# 1  2407104        2       2      3023.0            2017-03-28
# 2  2402600        2       2      3024.0            2012-09-24
# 3  2402600        2       2      3025.0            2011-02-17
# 4  2403608        2       2      3026.0            2012-01-09
#
#   dat_alteracao_fam  vlr_renda_media_fam dat_atualizacao_familia  \
# 0        2018-10-01                312.0              2017-12-04
# 1        2017-03-30                 75.0              2017-03-28
# 2        2016-04-15                 60.0              2016-04-15
# 3        2015-03-17                394.0              2015-03-17
# 4        2018-10-01                 66.0              2017-03-13
#
#    cod_local_domic_fam  cod_especie_domic_fam  ...  cod_familia_indigena_fam  \
# 0                  1.0                    1.0  ...                       2.0
# 1                  1.0                    1.0  ...                       2.0
# 2                  1.0                    1.0  ...                       2.0
# 3                  1.0                    1.0  ...                       2.0
# 4                  1.0                    1.0  ...                       2.0
#
#    ind_familia_quilombola_fam  nom_estab_assist_saude_fam  cod_eas_fam  \
# 0                         2.0                         NaN          NaN
# 1                         2.0          E S F MORADA DA FE    2473488.0
# 2                         2.0                         NaN          NaN
# 3                         2.0                         NaN          NaN
# 4                         2.0                         NaN          NaN
#
#          nom_centro_assist_fam  cod_centro_assist_fam  ind_parc_mds_fam  \
# 0                          NaN                    NaN             205.0
# 1  CRAS FABRICIO GOMES PEDROZA           2.407102e+10               0.0
# 2                          NaN                    NaN               0.0
# 3                          NaN                    NaN               0.0
# 4                          NaN                    NaN             205.0
#
#    marc_pbf  qtde_pessoas         peso.fam
# 0         0             3  550277487854843
# 1         1             2  550309766683735
# 2         1             5  550245146328323
# 3         0             2  550245146328323
# 4         1             3  550377509002049
#
# [5 rows x 31 columns]

# %%
cadUnicoRN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107509 entries, 0 to 107508
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   cd_ibge                        107509 non-null  int64
#  1   estrato                        107509 non-null  int64
#  2   classf                         107509 non-null  int64
#  3   id_familia                     107509 non-null  float64
#  4   dat_cadastramento_fam          107509 non-null  object
#  5   dat_alteracao_fam              107509 non-null  object
#  6   vlr_renda_media_fam            107507 non-null  float64
#  7   dat_atualizacao_familia        107509 non-null  object
#  8   cod_local_domic_fam            107340 non-null  float64
#  9   cod_especie_domic_fam          107340 non-null  float64
#  10  qtd_comodos_domic_fam          103736 non-null  float64
#  11  qtd_comodos_dormitorio_fam     103756 non-null  float64
#  12  cod_material_piso_fam          103774 non-null  float64
#  13  cod_material_domic_fam         103774 non-null  float64
#  14  cod_agua_canalizada_fam        103774 non-null  float64
#  15  cod_abaste_agua_domic_fam      103774 non-null  float64
#  16  cod_banheiro_domic_fam         103774 non-null  float64
#  17  cod_escoa_sanitario_domic_fam  100821 non-null  float64
#  18  cod_destino_lixo_domic_fam     103774 non-null  float64
#  19  cod_iluminacao_domic_fam       103774 non-null  float64
#  20  cod_calcamento_domic_fam       103774 non-null  float64
#  21  cod_familia_indigena_fam       107509 non-null  float64
#  22  ind_familia_quilombola_fam     107375 non-null  float64
#  23  nom_estab_assist_saude_fam     56111 non-null   object
#  24  cod_eas_fam                    56111 non-null   float64
#  25  nom_centro_assist_fam          26461 non-null   object
#  26  cod_centro_assist_fam          26461 non-null   float64
#  27  ind_parc_mds_fam               104924 non-null  float64
#  28  marc_pbf                       107509 non-null  int64
#  29  qtde_pessoas                   107509 non-null  int64
#  30  peso.fam                       107509 non-null  int64
# dtypes: float64(20), int64(6), object(5)
# memory usage: 25.4+ MB

# %%
cadUnicoRN.describe()
# Out:
#             cd_ibge        estrato         classf    id_familia  \
# count  1.075090e+05  107509.000000  107509.000000  1.075090e+05
# mean   2.406951e+06       1.697886       2.520877  1.921082e+06
# std    3.901902e+03       0.459177       0.727916  1.513747e+06
# min    2.400109e+06       1.000000       1.000000  3.022000e+03
# 25%    2.403251e+06       1.000000       2.000000  4.746440e+05
# 50%    2.408003e+06       2.000000       3.000000  1.722461e+06
# 75%    2.408953e+06       2.000000       3.000000  3.630907e+06
# max    2.415008e+06       2.000000       3.000000  4.280344e+06
#
#        vlr_renda_media_fam  cod_local_domic_fam  cod_especie_domic_fam  \
# count        107507.000000        107340.000000          107340.000000
# mean            236.222339             1.267710               1.036277
# std             317.581530             0.442768               0.202665
# min               0.000000             1.000000               1.000000
# 25%              33.000000             1.000000               1.000000
# 50%              80.000000             1.000000               1.000000
# 75%             318.000000             2.000000               1.000000
# max            2862.000000             2.000000               3.000000
#
#        qtd_comodos_domic_fam  qtd_comodos_dormitorio_fam  \
# count          103736.000000               103756.000000
# mean                4.796483                    1.782557
# std                 1.312256                    0.686313
# min                 0.000000                    0.000000
# 25%                 4.000000                    1.000000
# 50%                 5.000000                    2.000000
# 75%                 5.000000                    2.000000
# max                18.000000                   20.000000
#
#        cod_material_piso_fam  ...  cod_iluminacao_domic_fam  \
# count          103774.000000  ...             103774.000000
# mean                3.129618  ...                  1.191406
# std                 1.501747  ...                  0.793617
# min                 1.000000  ...                  1.000000
# 25%                 2.000000  ...                  1.000000
# 50%                 2.000000  ...                  1.000000
# 75%                 5.000000  ...                  1.000000
# max                 7.000000  ...                  6.000000
#
#        cod_calcamento_domic_fam  cod_familia_indigena_fam  \
# count             103774.000000             107509.000000
# mean                   1.835691                  1.998754
# std                    0.962607                  0.035283
# min                    1.000000                  1.000000
# 25%                    1.000000                  2.000000
# 50%                    1.000000                  2.000000
# 75%                    3.000000                  2.000000
# max                    3.000000                  2.000000
#
#        ind_familia_quilombola_fam   cod_eas_fam  cod_centro_assist_fam  \
# count               107375.000000  5.611100e+04           2.646100e+04
# mean                     1.995660  3.265626e+06           2.405803e+10
# std                      0.065735  1.562740e+06           4.716092e+08
# min                      1.000000  2.374501e+06           1.240140e+10
# 25%                      2.000000  2.409909e+06           2.404503e+10
# 50%                      2.000000  2.501988e+06           2.408002e+10
# 75%                      2.000000  3.173879e+06           2.410101e+10
# max                      2.000000  9.542973e+06           2.414900e+10
#
#        ind_parc_mds_fam       marc_pbf   qtde_pessoas      peso.fam
# count     104924.000000  107509.000000  107509.000000  1.075090e+05
# mean          48.024532       0.568864       2.744207  5.453849e+14
# std           90.439825       0.495237       1.376475  4.884139e+13
# min            0.000000       0.000000       1.000000  5.500495e+13
# 25%            0.000000       0.000000       2.000000  5.502272e+14
# 50%            0.000000       1.000000       3.000000  5.502490e+14
# 75%            0.000000       1.000000       4.000000  5.502516e+14
# max          306.000000       1.000000      16.000000  5.503847e+14
#
# [8 rows x 26 columns]

# %% [markdown]
# ### Pré-processamento dos dados

# %%
# removendo colunas que não se encontram em um formato adequado para o treinamento de ML
cadUnicoRN = cadUnicoRN.drop(columns=['dat_cadastramento_fam', 'dat_alteracao_fam', 'dat_atualizacao_familia', 'nom_estab_assist_saude_fam', 'cod_eas_fam', 'nom_centro_assist_fam', 'cod_centro_assist_fam'])

cadUnicoRN.head()
# Out:
#    cd_ibge  estrato  classf  id_familia  vlr_renda_media_fam  \
# 0  2414803        1       2      3022.0                312.0
# 1  2407104        2       2      3023.0                 75.0
# 2  2402600        2       2      3024.0                 60.0
# 3  2402600        2       2      3025.0                394.0
# 4  2403608        2       2      3026.0                 66.0
#
#    cod_local_domic_fam  cod_especie_domic_fam  qtd_comodos_domic_fam  \
# 0                  1.0                    1.0                    4.0
# 1                  1.0                    1.0                    4.0
# 2                  1.0                    1.0                    5.0
# 3                  1.0                    1.0                    5.0
# 4                  1.0                    1.0                    5.0
#
#    qtd_comodos_dormitorio_fam  cod_material_piso_fam  ...  \
# 0                         1.0                    2.0  ...
# 1                         1.0                    5.0  ...
# 2                         2.0                    2.0  ...
# 3                         2.0                    5.0  ...
# 4                         2.0                    2.0  ...
#
#    cod_escoa_sanitario_domic_fam  cod_destino_lixo_domic_fam  \
# 0                            3.0                         2.0
# 1                            2.0                         1.0
# 2                            2.0                         1.0
# 3                            3.0                         1.0
# 4                            2.0                         1.0
#
#    cod_iluminacao_domic_fam  cod_calcamento_domic_fam  \
# 0                       1.0                       1.0
# 1                       1.0                       1.0
# 2                       1.0                       3.0
# 3                       1.0                       1.0
# 4                       1.0                       1.0
#
#    cod_familia_indigena_fam  ind_familia_quilombola_fam  ind_parc_mds_fam  \
# 0                       2.0                         2.0             205.0
# 1                       2.0                         2.0               0.0
# 2                       2.0                         2.0               0.0
# 3                       2.0                         2.0               0.0
# 4                       2.0                         2.0             205.0
#
#    marc_pbf  qtde_pessoas         peso.fam
# 0         0             3  550277487854843
# 1         1             2  550309766683735
# 2         1             5  550245146328323
# 3         0             2  550245146328323
# 4         1             3  550377509002049
#
# [5 rows x 24 columns]

# %%
# verificando linhas duplicadas devido a mesclagem de diferentes datasets
duplicados = cadUnicoRN.duplicated(subset=['id_familia'], keep=False)

# print("Registros dublicados encontrados");
# print(cadUnicoRN[duplicados])

cadUnicoRN = cadUnicoRN.drop_duplicates(subset=['id_familia'], keep='last')

# %%
# colunas que precisam de tratamento de tipos
columns_to_convert = ['vlr_renda_media_fam', 'peso.fam']

for column in columns_to_convert:
    cadUnicoRN[column] = cadUnicoRN[column].replace(',', '.', regex=True).astype(float)

# verificando valores ausentes em cada coluna
missing_values = cadUnicoRN.isnull().sum()

print('As colunas com valores ausentes são:\n', (missing_values))
# Out:
# As colunas com valores ausentes são:
#  cd_ibge                             0
# estrato                             0
# classf                              0
# id_familia                          0
# vlr_renda_media_fam                 2
# cod_local_domic_fam               169
# cod_especie_domic_fam             169
# qtd_comodos_domic_fam            3773
# qtd_comodos_dormitorio_fam       3753
# cod_material_piso_fam            3735
# cod_material_domic_fam           3735
# cod_agua_canalizada_fam          3735
# cod_abaste_agua_domic_fam        3735
# cod_banheiro_domic_fam           3735
# cod_escoa_sanitario_domic_fam    6688
# cod_destino_lixo_domic_fam       3735
# cod_iluminacao_domic_fam         3735
# cod_calcamento_domic_fam         3735
# cod_familia_indigena_fam            0
# ind_familia_quilombola_fam        134
# ind_parc_mds_fam                 2585
# marc_pbf                            0
# qtde_pessoas                        0
# peso.fam                            0
# dtype: int64

# %%
columns_to_remove = ['cod_escoa_sanitario_domic_fam', 'ind_parc_mds_fam', 'id_familia']

cadUnicoRN = cadUnicoRN.drop(columns=columns_to_remove, axis=1)

# removendo linhas com valores ausentes
cadUnicoRN = cadUnicoRN.dropna()

missing_values = cadUnicoRN.isnull().sum()
print('As colunas com valores ausentes são:\n', (missing_values))
# Out:
# As colunas com valores ausentes são:
#  cd_ibge                       0
# estrato                       0
# classf                        0
# vlr_renda_media_fam           0
# cod_local_domic_fam           0
# cod_especie_domic_fam         0
# qtd_comodos_domic_fam         0
# qtd_comodos_dormitorio_fam    0
# cod_material_piso_fam         0
# cod_material_domic_fam        0
# cod_agua_canalizada_fam       0
# cod_abaste_agua_domic_fam     0
# cod_banheiro_domic_fam        0
# cod_destino_lixo_domic_fam    0
# cod_iluminacao_domic_fam      0
# cod_calcamento_domic_fam      0
# cod_familia_indigena_fam      0
# ind_familia_quilombola_fam    0
# marc_pbf                      0
# qtde_pessoas                  0
# peso.fam                      0
# dtype: int64

# %%
feature_names = cadUnicoRN.columns.tolist()
feature_names.remove('marc_pbf')

# %%
# identificando colunas com apenas um valor
single_value_columns = [col for col in cadUnicoRN.columns if cadUnicoRN[col].nunique() == 1 | 0]

print(f"Colunas com um único valor: {single_value_columns}")

cadUnicoRN = cadUnicoRN.drop(columns=single_value_columns)
# Out:
# Colunas com um único valor: ['cod_especie_domic_fam', 'cod_familia_indigena_fam']

# %% [markdown]
# ### Treinando modelo SVM

# %%
# analisando a distribuição da variável alvo (marc_pbf)
target_distribution = cadUnicoRN['marc_pbf'].value_counts(normalize=True) * 100

print(round(target_distribution))
# Out:
# marc_pbf
# 1    56.0
# 0    44.0
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# separar X (features) e y (target)
X = cadUnicoRN.drop('marc_pbf', axis=1)
y = cadUnicoRN['marc_pbf']

# treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# aplicando SMOTE para balancear o conjunto de treino
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

print(y_train_balanced.value_counts())
# Out:
# marc_pbf
# 1    40931
# 0    40931
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# aplicar padronização nas features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_balanced)
X_test_scaled = scaler.transform(X_test)

print("Primeiros dados escalados (padronizados):")
print(X_train_scaled[:5])
# Out:
# Primeiros dados escalados (padronizados):
# [[-1.22422344  0.6381351   0.67375686 -0.82305967  1.72612557 -0.6270288
#    0.31431134 -0.78187001 -0.28342815 -0.39675886  0.60058702 -0.1712738
#   -0.4737033  -0.23499453  1.24499114  0.06784592 -0.48524708  0.10157813]
#  [ 0.29120415  0.6381351  -2.05885728 -0.67023072 -0.59645328 -0.6270288
#   -1.16067934 -0.78187001 -0.28342815 -0.39675886 -0.48378954 -0.1712738
#   -0.4737033  -0.23499453 -0.87065493  0.06784592  0.24734419  0.10170806]
#  [ 0.29120415  0.6381351  -2.05885728  2.04095476 -0.59645328 -0.6270288
#   -1.16067934  1.24619104 -0.28342815 -0.39675886 -0.48378954 -0.1712738
#   -0.4737033   1.07243616 -0.87065493  0.06784592 -1.21783834  0.10170806]
#  [ 1.31115826  0.6381351  -0.69255021 -0.67023072  1.72612557 -1.40049407
#   -1.16067934 -0.78187001 -0.28342815 -0.39675886 -0.48378954 -0.1712738
#   -0.4737033  -0.23499453 -0.87065493  0.06784592 -0.48524708  0.10044604]
#  [-1.51089771 -1.56706628 -0.69255021  0.63492847  1.72612557  0.14643648
#    1.78930201 -1.45789037  6.55373205 -0.39675886  0.60058702 -0.1712738
#   -0.4737033  -0.23499453  1.24499114  0.06784592  0.97993545  0.10222729]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Inicializando o modelo SVM
svm_model = SVC(kernel='linear', random_state=42, C=1.0, gamma='scale')

# Treinando o modelo com os dados de treino escalados
svm_model.fit(X_train_scaled, y_train_balanced)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
# Previsões no conjunto de teste
y_pred = svm_model.predict(X_test_scaled)

# %%
# Acurácia
accuracy = accuracy_score(y_test, y_pred)
print(f"Acurácia: {accuracy:.2f}")

# Matriz de Confusão
conf_matrix = confusion_matrix(y_test, y_pred)
print("Matriz de Confusão:")
print(conf_matrix)

# Relatório de Classificação
class_report = classification_report(y_test, y_pred, target_names=['Classe 0', 'Classe 1'])
print("Relatório de Classificação:")
print(class_report)
# Out:
# Acurácia: 0.91
# Matriz de Confusão:
# [[11395  2187]
#  [  758 16738]]
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#     Classe 0       0.94      0.84      0.89     13582
#     Classe 1       0.88      0.96      0.92     17496
#
#     accuracy                           0.91     31078
#    macro avg       0.91      0.90      0.90     31078
# weighted avg       0.91      0.91      0.90     31078

# %% [markdown]
# ### Extraindo as melhores features

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# Selecionar as 5 melhores features (ajuste o valor de k conforme necessário)
k = 5
selector = SelectKBest(score_func=f_classif, k=k)

# %%
# Ajustar o selector ao conjunto de treino
X_train_selected = selector.fit_transform(X_train_scaled, y_train_balanced)
X_test_selected = selector.transform(X_test_scaled)

# Mostrar as melhores features
selected_features = selector.get_support(indices=True)
print(f"As {k} melhores features (índices):", selected_features)

# Exibir os nomes das melhores features
feature_names_array = np.array(X.columns)  # Convertendo para array
best_feature_names = feature_names_array[selected_features]
print(f"As {k} melhores features (nomes):", best_feature_names)
# Out:
# As 5 melhores features (índices): [ 3  5  7 14 16]
# As 5 melhores features (nomes): ['vlr_renda_media_fam' 'qtd_comodos_domic_fam' 'cod_material_piso_fam'
#  'cod_calcamento_domic_fam' 'qtde_pessoas']

# %%
# Treinando o modelo SVM com as melhores features
svm_model = SVC(kernel='rbf', random_state=42, C=1.0, gamma='scale')
svm_model.fit(X_train_selected, y_train_balanced)
# Out:
# SVC(random_state=42)

# %%
# Previsões com as melhores features
y_pred_selected = svm_model.predict(X_test_selected)

# Avaliar o modelo
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

accuracy = accuracy_score(y_test, y_pred_selected)
print(f"Acurácia com as {k} melhores features: {accuracy:.2f}")

conf_matrix = confusion_matrix(y_test, y_pred_selected)
print("Matriz de Confusão:")
print(conf_matrix)

class_report = classification_report(y_test, y_pred_selected, target_names=['Classe 0', 'Classe 1'])
print("Relatório de Classificação:")
print(class_report)
# Out:
# Acurácia com as 5 melhores features: 0.91
# Matriz de Confusão:
# [[11229  2353]
#  [  546 16950]]
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#     Classe 0       0.95      0.83      0.89     13582
#     Classe 1       0.88      0.97      0.92     17496
#
#     accuracy                           0.91     31078
#    macro avg       0.92      0.90      0.90     31078
# weighted avg       0.91      0.91      0.91     31078
