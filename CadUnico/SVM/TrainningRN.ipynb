# %% [markdown]
# <a href="https://colab.research.google.com/github/mariabandeira/AdministracaoPublica/blob/main/CadUnico/SVM/TrainningRN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Treinando para dados do RN

# %% [markdown]
# ### Recuperando os dados

# %%
import numpy as np
import pandas as pd

# %%
FILE_PATH_2018 = '/content/cadunico_rn_2018.csv'
cadUnicoRN2018 = pd.read_csv(FILE_PATH_2018, sep=';', low_memory=False)

# %%
FILE_PATH_2017 = '/content/cadunico_rn_2017.csv'
cadUnicoRN2017 = pd.read_csv(FILE_PATH_2017, sep=';', low_memory=False)

# %%
# Juntando os dois datasets
cadUnicoRN = pd.concat([cadUnicoRN2018, cadUnicoRN2017], ignore_index=True)

# %% [markdown]
# ### Entendendo a estrutura os dados

# %%
cadUnicoRN
# Out:
#         cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 0       2414803        1       2      3022.0            2017-12-04
# 1       2407104        2       2      3023.0            2017-03-28
# 2       2402600        2       2      3024.0            2012-09-24
# 3       2402600        2       2      3025.0            2011-02-17
# 4       2403608        2       2      3026.0            2012-01-09
# ...         ...      ...     ...         ...                   ...
# 221874  2408102        2       1   5135404.0            2006-12-15
# 221875  2408003        2       3   5135415.0            2003-03-13
# 221876  2408102        2       1   5135441.0            2011-04-25
# 221877  2407104        2       2   5135451.0            2002-08-20
# 221878  2408102        2       1   5135668.0            2003-03-13
#
#        dat_alteracao_fam vlr_renda_media_fam dat_atualizacao_familia  \
# 0             2018-10-01               312.0              2017-12-04
# 1             2017-03-30                75.0              2017-03-28
# 2             2016-04-15                60.0              2016-04-15
# 3             2015-03-17               394.0              2015-03-17
# 4             2018-10-01                66.0              2017-03-13
# ...                  ...                 ...                     ...
# 221874        2017-10-26                  50              2017-10-25
# 221875        2017-06-09                 187              2017-06-08
# 221876        2017-10-05                  55              2017-10-04
# 221877        2017-04-28                  60              2017-04-27
# 221878        2016-03-18                 197              2016-03-18
#
#         cod_local_domic_fam  cod_especie_domic_fam  ...  \
# 0                       1.0                    1.0  ...
# 1                       1.0                    1.0  ...
# 2                       1.0                    1.0  ...
# 3                       1.0                    1.0  ...
# 4                       1.0                    1.0  ...
# ...                     ...                    ...  ...
# 221874                  1.0                    1.0  ...
# 221875                  1.0                    1.0  ...
# 221876                  1.0                    1.0  ...
# 221877                  2.0                    1.0  ...
# 221878                  1.0                    1.0  ...
#
#         cod_familia_indigena_fam  ind_familia_quilombola_fam  \
# 0                            2.0                         2.0
# 1                            2.0                         2.0
# 2                            2.0                         2.0
# 3                            2.0                         2.0
# 4                            2.0                         2.0
# ...                          ...                         ...
# 221874                       2.0                         2.0
# 221875                       2.0                         2.0
# 221876                       2.0                         2.0
# 221877                       2.0                         2.0
# 221878                       2.0                         2.0
#
#                         nom_estab_assist_saude_fam  cod_eas_fam  \
# 0                                              NaN          NaN
# 1                               E S F MORADA DA FE    2473488.0
# 2                                              NaN          NaN
# 3                                              NaN          NaN
# 4                                              NaN          NaN
# ...                                            ...          ...
# 221874       UNIDADE DE SAUDE FAMILIAR COMUNITARIA    2653966.0
# 221875  CENTRO DE ATENCAO INTEGRADO A CRIANCA CAIC    2503670.0
# 221876                                         NaN          NaN
# 221877                               E S F TRAIRAS    2473461.0
# 221878                                         NaN          NaN
#
#               nom_centro_assist_fam  cod_centro_assist_fam  ind_parc_mds_fam  \
# 0                               NaN                    NaN             205.0
# 1       CRAS FABRICIO GOMES PEDROZA           2.407102e+10               0.0
# 2                               NaN                    NaN               0.0
# 3                               NaN                    NaN               0.0
# 4                               NaN                    NaN             205.0
# ...                             ...                    ...               ...
# 221874                          NaN                    NaN               0.0
# 221875                          NaN                    NaN               0.0
# 221876                          NaN                    NaN               0.0
# 221877         CRAS TAVARES DE LIRA           2.407100e+10             205.0
# 221878                          NaN                    NaN               0.0
#
#         marc_pbf  qtde_pessoas          peso.fam
# 0              0             3   550277487854843
# 1              1             2   550309766683735
# 2              1             5   550245146328323
# 3              0             2   550245146328323
# 4              1             3   550377509002049
# ...          ...           ...               ...
# 221874         0             3   5,1686353205331
# 221875         0             5  5,16865108822219
# 221876         1             2   5,1686353205331
# 221877         1             2  5,16883192736593
# 221878         0             4   5,1686353205331
#
# [221879 rows x 31 columns]

# %%
cadUnicoRN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221879 entries, 0 to 221878
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   cd_ibge                        221879 non-null  int64
#  1   estrato                        221879 non-null  int64
#  2   classf                         221879 non-null  int64
#  3   id_familia                     221879 non-null  float64
#  4   dat_cadastramento_fam          221879 non-null  object
#  5   dat_alteracao_fam              221879 non-null  object
#  6   vlr_renda_media_fam            221877 non-null  object
#  7   dat_atualizacao_familia        221879 non-null  object
#  8   cod_local_domic_fam            221549 non-null  float64
#  9   cod_especie_domic_fam          221549 non-null  float64
#  10  qtd_comodos_domic_fam          214357 non-null  float64
#  11  qtd_comodos_dormitorio_fam     214400 non-null  float64
#  12  cod_material_piso_fam          214435 non-null  float64
#  13  cod_material_domic_fam         214435 non-null  float64
#  14  cod_agua_canalizada_fam        214435 non-null  float64
#  15  cod_abaste_agua_domic_fam      214435 non-null  float64
#  16  cod_banheiro_domic_fam         214435 non-null  float64
#  17  cod_escoa_sanitario_domic_fam  208135 non-null  float64
#  18  cod_destino_lixo_domic_fam     214435 non-null  float64
#  19  cod_iluminacao_domic_fam       214435 non-null  float64
#  20  cod_calcamento_domic_fam       214435 non-null  float64
#  21  cod_familia_indigena_fam       221879 non-null  float64
#  22  ind_familia_quilombola_fam     221592 non-null  float64
#  23  nom_estab_assist_saude_fam     108565 non-null  object
#  24  cod_eas_fam                    108565 non-null  float64
#  25  nom_centro_assist_fam          51261 non-null   object
#  26  cod_centro_assist_fam          51261 non-null   float64
#  27  ind_parc_mds_fam               209111 non-null  float64
#  28  marc_pbf                       221879 non-null  int64
#  29  qtde_pessoas                   221879 non-null  int64
#  30  peso.fam                       221879 non-null  object
# dtypes: float64(19), int64(5), object(7)
# memory usage: 52.5+ MB

# %%
cadUnicoRN.describe()
# Out:
#             cd_ibge        estrato         classf    id_familia  \
# count  2.218790e+05  221879.000000  221879.000000  2.218790e+05
# mean   2.406940e+06       1.704627       2.526819  2.255531e+06
# std    3.912087e+03       0.456211       0.725514  1.533416e+06
# min    2.400109e+06       1.000000       1.000000  8.600000e+01
# 25%    2.403251e+06       1.000000       2.000000  4.942165e+05
# 50%    2.408003e+06       2.000000       3.000000  2.197676e+06
# 75%    2.409100e+06       2.000000       3.000000  3.638111e+06
# max    2.415008e+06       2.000000       3.000000  5.135668e+06
#
#        cod_local_domic_fam  cod_especie_domic_fam  qtd_comodos_domic_fam  \
# count        221549.000000          221549.000000          214357.000000
# mean              1.267544               1.034936               4.796573
# std               0.442679               0.198410               1.315595
# min               1.000000               1.000000               0.000000
# 25%               1.000000               1.000000               4.000000
# 50%               1.000000               1.000000               5.000000
# 75%               2.000000               1.000000               5.000000
# max               2.000000               3.000000              18.000000
#
#        qtd_comodos_dormitorio_fam  cod_material_piso_fam  \
# count               214400.000000          214435.000000
# mean                     1.787253               3.074456
# std                      0.682516               1.490955
# min                      0.000000               1.000000
# 25%                      1.000000               2.000000
# 50%                      2.000000               2.000000
# 75%                      2.000000               5.000000
# max                     20.000000               7.000000
#
#        cod_material_domic_fam  ...  cod_destino_lixo_domic_fam  \
# count           214435.000000  ...               214435.000000
# mean                 1.183314  ...                    1.392627
# std                  0.632844  ...                    0.819804
# min                  1.000000  ...                    1.000000
# 25%                  1.000000  ...                    1.000000
# 50%                  1.000000  ...                    1.000000
# 75%                  1.000000  ...                    1.000000
# max                  8.000000  ...                    6.000000
#
#        cod_iluminacao_domic_fam  cod_calcamento_domic_fam  \
# count             214435.000000             214435.000000
# mean                   1.191606                  1.844666
# std                    0.794005                  0.963536
# min                    1.000000                  1.000000
# 25%                    1.000000                  1.000000
# 50%                    1.000000                  1.000000
# 75%                    1.000000                  3.000000
# max                    6.000000                  3.000000
#
#        cod_familia_indigena_fam  ind_familia_quilombola_fam   cod_eas_fam  \
# count             221879.000000               221592.000000  1.085650e+05
# mean                   1.998707                    1.996232  3.247226e+06
# std                    0.035942                    0.061270  1.533319e+06
# min                    1.000000                    1.000000  2.374501e+06
# 25%                    2.000000                    2.000000  2.410168e+06
# 50%                    2.000000                    2.000000  2.501988e+06
# 75%                    2.000000                    2.000000  3.173879e+06
# max                    2.000000                    2.000000  9.542973e+06
#
#        cod_centro_assist_fam  ind_parc_mds_fam       marc_pbf   qtde_pessoas
# count           5.126100e+04     209111.000000  221879.000000  221879.000000
# mean            2.406014e+10         47.804233       0.575318       2.813376
# std             4.477709e+08         90.152775       0.494296       1.393759
# min             1.240140e+10          0.000000       0.000000       1.000000
# 25%             2.404503e+10          0.000000       0.000000       2.000000
# 50%             2.408002e+10          0.000000       1.000000       3.000000
# 75%             2.410250e+10          0.000000       1.000000       4.000000
# max             2.414900e+10        306.000000       1.000000      16.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# ### Pré-processamento dos dados

# %%
# removendo colunas que não se encontram em um formato adequado para o treinamento de ML
cadUnicoRN = cadUnicoRN.drop(columns=['dat_cadastramento_fam', 'dat_alteracao_fam', 'dat_atualizacao_familia', 'nom_estab_assist_saude_fam', 'cod_eas_fam', 'nom_centro_assist_fam', 'cod_centro_assist_fam'])

cadUnicoRN.head()
# Out:
#    cd_ibge  estrato  classf  id_familia vlr_renda_media_fam  \
# 0  2414803        1       2      3022.0               312.0
# 1  2407104        2       2      3023.0                75.0
# 2  2402600        2       2      3024.0                60.0
# 3  2402600        2       2      3025.0               394.0
# 4  2403608        2       2      3026.0                66.0
#
#    cod_local_domic_fam  cod_especie_domic_fam  qtd_comodos_domic_fam  \
# 0                  1.0                    1.0                    4.0
# 1                  1.0                    1.0                    4.0
# 2                  1.0                    1.0                    5.0
# 3                  1.0                    1.0                    5.0
# 4                  1.0                    1.0                    5.0
#
#    qtd_comodos_dormitorio_fam  cod_material_piso_fam  ...  \
# 0                         1.0                    2.0  ...
# 1                         1.0                    5.0  ...
# 2                         2.0                    2.0  ...
# 3                         2.0                    5.0  ...
# 4                         2.0                    2.0  ...
#
#    cod_escoa_sanitario_domic_fam  cod_destino_lixo_domic_fam  \
# 0                            3.0                         2.0
# 1                            2.0                         1.0
# 2                            2.0                         1.0
# 3                            3.0                         1.0
# 4                            2.0                         1.0
#
#    cod_iluminacao_domic_fam  cod_calcamento_domic_fam  \
# 0                       1.0                       1.0
# 1                       1.0                       1.0
# 2                       1.0                       3.0
# 3                       1.0                       1.0
# 4                       1.0                       1.0
#
#    cod_familia_indigena_fam  ind_familia_quilombola_fam  ind_parc_mds_fam  \
# 0                       2.0                         2.0             205.0
# 1                       2.0                         2.0               0.0
# 2                       2.0                         2.0               0.0
# 3                       2.0                         2.0               0.0
# 4                       2.0                         2.0             205.0
#
#    marc_pbf  qtde_pessoas         peso.fam
# 0         0             3  550277487854843
# 1         1             2  550309766683735
# 2         1             5  550245146328323
# 3         0             2  550245146328323
# 4         1             3  550377509002049
#
# [5 rows x 24 columns]

# %%
# verificando linhas duplicadas devido a mesclagem de diferentes datasets
duplicados = cadUnicoRN.duplicated(subset=['id_familia'], keep=False)

# print("Registros dublicados encontrados");
# print(cadUnicoRN[duplicados])

cadUnicoRN = cadUnicoRN.drop_duplicates(subset=['id_familia'], keep='last')

# %%
# colunas que precisam de tratamento de tipos
columns_to_convert = ['vlr_renda_media_fam', 'peso.fam']

for column in columns_to_convert:
    cadUnicoRN[column] = cadUnicoRN[column].replace(',', '.', regex=True).astype(float)

# verificando valores ausentes em cada coluna
missing_values = cadUnicoRN.isnull().sum()

print('As colunas com valores ausentes são:\n', (missing_values))
# Out:
# As colunas com valores ausentes são:
#  cd_ibge                              0
# estrato                              0
# classf                               0
# id_familia                           0
# vlr_renda_media_fam                  2
# cod_local_domic_fam                322
# cod_especie_domic_fam              322
# qtd_comodos_domic_fam             7438
# qtd_comodos_dormitorio_fam        7395
# cod_material_piso_fam             7360
# cod_material_domic_fam            7360
# cod_agua_canalizada_fam           7360
# cod_abaste_agua_domic_fam         7360
# cod_banheiro_domic_fam            7360
# cod_escoa_sanitario_domic_fam    13587
# cod_destino_lixo_domic_fam        7360
# cod_iluminacao_domic_fam          7360
# cod_calcamento_domic_fam          7360
# cod_familia_indigena_fam             0
# ind_familia_quilombola_fam         282
# ind_parc_mds_fam                 12716
# marc_pbf                             0
# qtde_pessoas                         0
# peso.fam                             0
# dtype: int64

# %%
columns_to_remove = ['cod_escoa_sanitario_domic_fam', 'ind_parc_mds_fam', 'id_familia']

cadUnicoRN = cadUnicoRN.drop(columns=columns_to_remove, axis=1)

# removendo linhas com valores ausentes
cadUnicoRN = cadUnicoRN.dropna()

missing_values = cadUnicoRN.isnull().sum()
print('As colunas com valores ausentes são:\n', (missing_values))
# Out:
# As colunas com valores ausentes são:
#  cd_ibge                       0
# estrato                       0
# classf                        0
# vlr_renda_media_fam           0
# cod_local_domic_fam           0
# cod_especie_domic_fam         0
# qtd_comodos_domic_fam         0
# qtd_comodos_dormitorio_fam    0
# cod_material_piso_fam         0
# cod_material_domic_fam        0
# cod_agua_canalizada_fam       0
# cod_abaste_agua_domic_fam     0
# cod_banheiro_domic_fam        0
# cod_destino_lixo_domic_fam    0
# cod_iluminacao_domic_fam      0
# cod_calcamento_domic_fam      0
# cod_familia_indigena_fam      0
# ind_familia_quilombola_fam    0
# marc_pbf                      0
# qtde_pessoas                  0
# peso.fam                      0
# dtype: int64

# %%
feature_names = cadUnicoRN.columns.tolist()
feature_names.remove('marc_pbf')

# %%
# identificando colunas com apenas um valor
single_value_columns = [col for col in cadUnicoRN.columns if cadUnicoRN[col].nunique() == 1 | 0]

print(f"Colunas com um único valor: {single_value_columns}")

cadUnicoRN = cadUnicoRN.drop(columns=single_value_columns)
# Out:
# Colunas com um único valor: ['cod_especie_domic_fam', 'cod_familia_indigena_fam']

# %% [markdown]
# ### Treinando modelo SVM

# %%
# analisando a distribuição da variável alvo (marc_pbf)
target_distribution = cadUnicoRN['marc_pbf'].value_counts(normalize=True) * 100

print(round(target_distribution))
# Out:
# marc_pbf
# 1    57.0
# 0    43.0
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# separar X (features) e y (target)
X = cadUnicoRN.drop('marc_pbf', axis=1)
y = cadUnicoRN['marc_pbf']

# treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# aplicando SMOTE para balancear o conjunto de treino
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

print(y_train_balanced.value_counts())
# Out:
# marc_pbf
# 1    84579
# 0    84579
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# aplicar padronização nas features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_balanced)
X_test_scaled = scaler.transform(X_test)

print("Primeiros dados escalados (padronizados):")
print(X_train_scaled[:5])
# Out:
# Primeiros dados escalados (padronizados):
# [[-0.97135047 -1.59104008  0.67161232 -0.77931601 -0.59584076  0.13211629
#    0.30321332 -0.75657692 -0.28550106 -0.40097618 -0.47676145 -0.16847137
#   -0.47885812 -0.2366822   1.2351308   0.0599859   0.18895769 -0.95299129]
#  [ 1.67276016 -1.59104008  0.67161232  1.964772   -0.59584076  0.9038267
#    1.80214387 -0.75657692 -0.28550106 -0.40097618 -0.47676145 -0.16847137
#   -0.47885812 -0.2366822  -0.876968    0.0599859  -1.26651812 -0.95299129]
#  [-0.95865708  0.62851968 -0.69721543  2.97293292 -0.59584076  0.13211629
#    0.30321332  1.2719604  -0.28550106 -0.40097618 -0.47676145 -0.16847137
#   -0.47885812 -0.2366822  -0.876968    0.0599859  -1.26651812 -0.95299129]
#  [ 1.90564499 -1.59104008  0.67161232 -0.79821902 -0.59584076 -0.63959411
#    0.30321332 -0.75657692 -0.28550106 -0.40097618 -0.47676145 -0.16847137
#   -0.47885812 -0.2366822  -0.876968    0.0599859   0.91669559  1.05123854]
#  [-0.53070854 -1.59104008  0.67161232 -0.80767053 -0.59584076 -1.41130451
#   -1.19571724 -0.75657692  1.36123702  2.55649513  2.8203035  -0.16847137
#   -0.47885812 -0.2366822  -0.876968    0.0599859  -1.26651812  1.05123854]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Inicializando o modelo SVM
svm_model = SVC(kernel='linear', random_state=42, C=1.0, gamma='scale')

# Treinando o modelo com os dados de treino escalados
svm_model.fit(X_train_scaled, y_train_balanced)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
# Previsões no conjunto de teste
y_pred = svm_model.predict(X_test_scaled)

# %%
# Acurácia
accuracy = accuracy_score(y_test, y_pred)
print(f"Acurácia: {accuracy:.2f}")

# Matriz de Confusão
conf_matrix = confusion_matrix(y_test, y_pred)
print("Matriz de Confusão:")
print(conf_matrix)

# Relatório de Classificação
class_report = classification_report(y_test, y_pred, target_names=['Classe 0', 'Classe 1'])
print("Relatório de Classificação:")
print(class_report)
# Out:
# Acurácia: 0.90
# Matriz de Confusão:
# [[22764  4365]
#  [ 1923 34470]]
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#     Classe 0       0.92      0.84      0.88     27129
#     Classe 1       0.89      0.95      0.92     36393
#
#     accuracy                           0.90     63522
#    macro avg       0.90      0.89      0.90     63522
# weighted avg       0.90      0.90      0.90     63522

# %% [markdown]
# ### Extraindo as melhores features

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# Selecionar as 5 melhores features (ajuste o valor de k conforme necessário)
k = 5
selector = SelectKBest(score_func=f_classif, k=k)

# %%
# Ajustar o selector ao conjunto de treino
X_train_selected = selector.fit_transform(X_train_scaled, y_train_balanced)
X_test_selected = selector.transform(X_test_scaled)

# Mostrar as melhores features
selected_features = selector.get_support(indices=True)
print(f"As {k} melhores features (índices):", selected_features)

# Exibir os nomes das melhores features
feature_names_array = np.array(X.columns)  # Convertendo para array
best_feature_names = feature_names_array[selected_features]
print(f"As {k} melhores features (nomes):", best_feature_names)
# Out:
# As 5 melhores features (índices): [ 3  5  7 14 16]
# As 5 melhores features (nomes): ['vlr_renda_media_fam' 'qtd_comodos_domic_fam' 'cod_material_piso_fam'
#  'cod_calcamento_domic_fam' 'qtde_pessoas']

# %%
# Treinando o modelo SVM com as melhores features
svm_model = SVC(kernel='rbf', random_state=42, C=1.0, gamma='scale')
svm_model.fit(X_train_selected, y_train_balanced)
# Out:
# SVC(random_state=42)

# %%
# Previsões com as melhores features
y_pred_selected = svm_model.predict(X_test_selected)

# Avaliar o modelo
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

accuracy = accuracy_score(y_test, y_pred_selected)
print(f"Acurácia com as {k} melhores features: {accuracy:.2f}")

conf_matrix = confusion_matrix(y_test, y_pred_selected)
print("Matriz de Confusão:")
print(conf_matrix)

class_report = classification_report(y_test, y_pred_selected, target_names=['Classe 0', 'Classe 1'])
print("Relatório de Classificação:")
print(class_report)
# Out:
# Acurácia com as 5 melhores features: 0.90
# Matriz de Confusão:
# [[22311  4818]
#  [ 1338 35055]]
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#     Classe 0       0.94      0.82      0.88     27129
#     Classe 1       0.88      0.96      0.92     36393
#
#     accuracy                           0.90     63522
#    macro avg       0.91      0.89      0.90     63522
# weighted avg       0.91      0.90      0.90     63522
