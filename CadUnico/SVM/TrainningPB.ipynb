# %% [markdown]
# <a href="https://colab.research.google.com/github/mariabandeira/AdministracaoPublica/blob/main/CadUnico/SVM/TrainningPB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Treinando para dados do PB

# %% [markdown]
# ### Recuperando os dados

# %%
import numpy as np
import pandas as pd

# %%
FILE_PATH_2018 = '/content/cadunico_pb_2018.csv'
cadUnicoPB2018 = pd.read_csv(FILE_PATH_2018, sep=';', low_memory=False)

# %%
FILE_PATH_2017 = '/content/cadunico_pb_2017.csv'
cadUnicoPB2017 = pd.read_csv(FILE_PATH_2017, sep=';', low_memory=False)

# %%
FILE_PATH_2016 = '/content/cadunico_pb_2016.csv'
cadUnicoPB2016 = pd.read_csv(FILE_PATH_2016, sep=';', low_memory=False)

# %%
# Juntando os dois datasets
cadUnicoPB = pd.concat([cadUnicoPB2018, cadUnicoPB2017, cadUnicoPB2016], ignore_index=True)

# %% [markdown]
# ### Entendendo a estrutura os dados

# %%
cadUnicoPB.head()
# Out:
#    index  cd_ibge  estrato  classf  id_familia dat_cadastramento_fam  \
# 0  56468  2513703        2       2     68260.0            2009-04-04
# 1  56469  2512408        1       2     68261.0            2002-03-18
# 2  56470  2512507        2       2     68262.0            2018-07-26
# 3  56471  2515807        1       2     68263.0            2002-02-20
# 4  56472  2501807        2       2     68264.0            2006-10-21
#
#   dat_alteracao_fam vlr_renda_media_fam dat_atualizacao_familia  \
# 0        2018-11-20               477.0              2018-11-20
# 1        2018-09-30                23.0              2018-04-27
# 2        2018-10-02                38.0              2018-07-26
# 3        2018-09-30                 0.0              2017-05-18
# 4        2018-09-30                33.0              2017-11-30
#
#    cod_local_domic_fam  ...  cod_familia_indigena_fam  \
# 0                  1.0  ...                       2.0
# 1                  2.0  ...                       2.0
# 2                  1.0  ...                       2.0
# 3                  2.0  ...                       2.0
# 4                  1.0  ...                       2.0
#
#    ind_familia_quilombola_fam  nom_estab_assist_saude_fam  cod_eas_fam  \
# 0                         2.0                         NaN          NaN
# 1                         2.0                         NaN          NaN
# 2                         2.0              UBSF LIGEIRO I    2612992.0
# 3                         2.0                         NaN          NaN
# 4                         2.0                         NaN          NaN
#
#    nom_centro_assist_fam  cod_centro_assist_fam  ind_parc_mds_fam  marc_pbf  \
# 0                    NaN                    NaN               0.0         0
# 1                    NaN                    NaN               0.0         1
# 2                    NaN                    NaN               0.0         1
# 3                    NaN                    NaN               0.0         1
# 4                    NaN                    NaN               0.0         1
#
#    qtde_pessoas         peso.fam
# 0             2  550292618438458
# 1             3  550256266088136
# 2             6  550245146328323
# 3             1  550256266088136
# 4             3  550245146328323
#
# [5 rows x 32 columns]

# %%
cadUnicoPB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435656 entries, 0 to 435655
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   index                          435656 non-null  int64
#  1   cd_ibge                        435656 non-null  int64
#  2   estrato                        435656 non-null  int64
#  3   classf                         435656 non-null  int64
#  4   id_familia                     435656 non-null  float64
#  5   dat_cadastramento_fam          435656 non-null  object
#  6   dat_alteracao_fam              435656 non-null  object
#  7   vlr_renda_media_fam            435654 non-null  object
#  8   dat_atualizacao_familia        435656 non-null  object
#  9   cod_local_domic_fam            435519 non-null  float64
#  10  cod_especie_domic_fam          435519 non-null  float64
#  11  qtd_comodos_domic_fam          418178 non-null  float64
#  12  qtd_comodos_dormitorio_fam     418287 non-null  float64
#  13  cod_material_piso_fam          418364 non-null  float64
#  14  cod_material_domic_fam         418364 non-null  float64
#  15  cod_agua_canalizada_fam        418364 non-null  float64
#  16  cod_abaste_agua_domic_fam      418364 non-null  float64
#  17  cod_banheiro_domic_fam         418364 non-null  float64
#  18  cod_escoa_sanitario_domic_fam  391522 non-null  float64
#  19  cod_destino_lixo_domic_fam     418364 non-null  float64
#  20  cod_iluminacao_domic_fam       418364 non-null  float64
#  21  cod_calcamento_domic_fam       418364 non-null  float64
#  22  cod_familia_indigena_fam       435656 non-null  float64
#  23  ind_familia_quilombola_fam     433851 non-null  float64
#  24  nom_estab_assist_saude_fam     231277 non-null  object
#  25  cod_eas_fam                    231277 non-null  float64
#  26  nom_centro_assist_fam          82306 non-null   object
#  27  cod_centro_assist_fam          82306 non-null   float64
#  28  ind_parc_mds_fam               367821 non-null  float64
#  29  marc_pbf                       435656 non-null  int64
#  30  qtde_pessoas                   435656 non-null  int64
#  31  peso.fam                       435656 non-null  object
# dtypes: float64(19), int64(6), object(7)
# memory usage: 106.4+ MB

# %%
cadUnicoPB.describe()
# Out:
#               index       cd_ibge        estrato         classf    id_familia  \
# count  4.356560e+05  4.356560e+05  435656.000000  435656.000000  4.356560e+05
# mean   2.069215e+06  2.508092e+06       1.670084       2.474487  2.172231e+06
# std    1.475912e+06  4.660160e+03       0.470183       0.709445  1.526303e+06
# min    8.000000e+00  2.500106e+06       1.000000       1.000000  9.000000e+00
# 25%    6.627548e+05  2.504009e+06       1.000000       2.000000  7.085218e+05
# 50%    1.800288e+06  2.507507e+06       2.000000       3.000000  1.912768e+06
# 75%    3.541064e+06  2.512101e+06       2.000000       3.000000  3.544558e+06
# max    5.130622e+06  2.517407e+06       2.000000       3.000000  5.135650e+06
#
#        cod_local_domic_fam  cod_especie_domic_fam  qtd_comodos_domic_fam  \
# count        435519.000000          435519.000000          418178.000000
# mean              1.243333               1.041199               4.677683
# std               0.429095               0.207666               1.309749
# min               1.000000               1.000000               0.000000
# 25%               1.000000               1.000000               4.000000
# 50%               1.000000               1.000000               5.000000
# 75%               1.000000               1.000000               5.000000
# max               2.000000               3.000000              19.000000
#
#        qtd_comodos_dormitorio_fam  cod_material_piso_fam  ...  \
# count               418287.000000          418364.000000  ...
# mean                     1.794949               2.752923  ...
# std                      0.685493               1.372751  ...
# min                      0.000000               1.000000  ...
# 25%                      1.000000               2.000000  ...
# 50%                      2.000000               2.000000  ...
# 75%                      2.000000               5.000000  ...
# max                     20.000000               7.000000  ...
#
#        cod_destino_lixo_domic_fam  cod_iluminacao_domic_fam  \
# count               418364.000000             418364.000000
# mean                     1.502483                  1.167684
# std                      0.925876                  0.712860
# min                      1.000000                  1.000000
# 25%                      1.000000                  1.000000
# 50%                      1.000000                  1.000000
# 75%                      1.000000                  1.000000
# max                      6.000000                  6.000000
#
#        cod_calcamento_domic_fam  cod_familia_indigena_fam  \
# count             418364.000000             435656.000000
# mean                   1.962282                  1.995857
# std                    0.982736                  0.064234
# min                    1.000000                  1.000000
# 25%                    1.000000                  2.000000
# 50%                    1.000000                  2.000000
# 75%                    3.000000                  2.000000
# max                    3.000000                  2.000000
#
#        ind_familia_quilombola_fam   cod_eas_fam  cod_centro_assist_fam  \
# count               433851.000000  2.312770e+05           8.230600e+04
# mean                     1.995980  2.918613e+06           2.492482e+10
# std                      0.063275  9.737563e+05           1.430333e+09
# min                      1.000000  2.313499e+06           1.250430e+10
# 25%                      2.000000  2.357100e+06           2.504400e+10
# 50%                      2.000000  2.606690e+06           2.508700e+10
# 75%                      2.000000  3.015823e+06           2.513352e+10
# max                      2.000000  9.419624e+06           2.517400e+10
#
#        ind_parc_mds_fam       marc_pbf   qtde_pessoas
# count     367821.000000  435656.000000  435656.000000
# mean          20.660248       0.647206       2.785565
# std           64.138938       0.477840       1.432760
# min            0.000000       0.000000       1.000000
# 25%            0.000000       0.000000       2.000000
# 50%            0.000000       1.000000       3.000000
# 75%            0.000000       1.000000       4.000000
# max          306.000000       1.000000      31.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# ### Pré-processamento dos dados

# %%
# removendo colunas que não se encontram em um formato adequado para o treinamento de ML
cadUnicoPB = cadUnicoPB.drop(columns=['dat_cadastramento_fam', 'dat_alteracao_fam', 'dat_atualizacao_familia', 'nom_estab_assist_saude_fam', 'cod_eas_fam', 'nom_centro_assist_fam', 'cod_centro_assist_fam'])

cadUnicoPB.head()
# Out:
#    index  cd_ibge  estrato  classf  id_familia vlr_renda_media_fam  \
# 0  56468  2513703        2       2     68260.0               477.0
# 1  56469  2512408        1       2     68261.0                23.0
# 2  56470  2512507        2       2     68262.0                38.0
# 3  56471  2515807        1       2     68263.0                 0.0
# 4  56472  2501807        2       2     68264.0                33.0
#
#    cod_local_domic_fam  cod_especie_domic_fam  qtd_comodos_domic_fam  \
# 0                  1.0                    1.0                    5.0
# 1                  2.0                    1.0                    5.0
# 2                  1.0                    1.0                    5.0
# 3                  2.0                    1.0                    4.0
# 4                  1.0                    1.0                    5.0
#
#    qtd_comodos_dormitorio_fam  ...  cod_escoa_sanitario_domic_fam  \
# 0                         2.0  ...                            3.0
# 1                         1.0  ...                            NaN
# 2                         2.0  ...                            1.0
# 3                         1.0  ...                            NaN
# 4                         2.0  ...                            1.0
#
#    cod_destino_lixo_domic_fam  cod_iluminacao_domic_fam  \
# 0                         1.0                       1.0
# 1                         1.0                       3.0
# 2                         1.0                       1.0
# 3                         3.0                       1.0
# 4                         1.0                       1.0
#
#    cod_calcamento_domic_fam  cod_familia_indigena_fam  \
# 0                       1.0                       2.0
# 1                       3.0                       2.0
# 2                       1.0                       2.0
# 3                       3.0                       2.0
# 4                       1.0                       2.0
#
#    ind_familia_quilombola_fam  ind_parc_mds_fam  marc_pbf  qtde_pessoas  \
# 0                         2.0               0.0         0             2
# 1                         2.0               0.0         1             3
# 2                         2.0               0.0         1             6
# 3                         2.0               0.0         1             1
# 4                         2.0               0.0         1             3
#
#           peso.fam
# 0  550292618438458
# 1  550256266088136
# 2  550245146328323
# 3  550256266088136
# 4  550245146328323
#
# [5 rows x 25 columns]

# %%
# verificando linhas duplicadas devido a mesclagem de diferentes datasets
duplicados = cadUnicoPB.duplicated(subset=['id_familia'], keep=False)

# print("Registros dublicados encontrados");
# print(cadUnicoPB[duplicados])

cadUnicoPB = cadUnicoPB.drop_duplicates(subset=['id_familia'], keep='last')

# %%
# colunas que precisam de tratamento de tipos
columns_to_convert = ['vlr_renda_media_fam', 'peso.fam']

for column in columns_to_convert:
    cadUnicoPB[column] = cadUnicoPB[column].replace(',', '.', regex=True).astype(float)

# verificando valores ausentes em cada coluna
missing_values = cadUnicoPB.isnull().sum()

print('As colunas com valores ausentes são:\n', (missing_values))
# Out:
# As colunas com valores ausentes são:
#  index                                0
# cd_ibge                              0
# estrato                              0
# classf                               0
# id_familia                           0
# vlr_renda_media_fam                  2
# cod_local_domic_fam                129
# cod_especie_domic_fam              129
# qtd_comodos_domic_fam            15089
# qtd_comodos_dormitorio_fam       14990
# cod_material_piso_fam            14920
# cod_material_domic_fam           14920
# cod_agua_canalizada_fam          14920
# cod_abaste_agua_domic_fam        14920
# cod_banheiro_domic_fam           14920
# cod_escoa_sanitario_domic_fam    37800
# cod_destino_lixo_domic_fam       14920
# cod_iluminacao_domic_fam         14920
# cod_calcamento_domic_fam         14920
# cod_familia_indigena_fam             0
# ind_familia_quilombola_fam        1465
# ind_parc_mds_fam                 65423
# marc_pbf                             0
# qtde_pessoas                         0
# peso.fam                             0
# dtype: int64

# %%
columns_to_remove = ['cod_escoa_sanitario_domic_fam', 'ind_parc_mds_fam', 'id_familia']

cadUnicoRN = cadUnicoPB.drop(columns=columns_to_remove, axis=1)

# removendo linhas com valores ausentes
cadUnicoPB = cadUnicoPB.dropna()

missing_values = cadUnicoPB.isnull().sum()
print('As colunas com valores ausentes são:\n', (missing_values))
# Out:
# As colunas com valores ausentes são:
#  index                            0
# cd_ibge                          0
# estrato                          0
# classf                           0
# id_familia                       0
# vlr_renda_media_fam              0
# cod_local_domic_fam              0
# cod_especie_domic_fam            0
# qtd_comodos_domic_fam            0
# qtd_comodos_dormitorio_fam       0
# cod_material_piso_fam            0
# cod_material_domic_fam           0
# cod_agua_canalizada_fam          0
# cod_abaste_agua_domic_fam        0
# cod_banheiro_domic_fam           0
# cod_escoa_sanitario_domic_fam    0
# cod_destino_lixo_domic_fam       0
# cod_iluminacao_domic_fam         0
# cod_calcamento_domic_fam         0
# cod_familia_indigena_fam         0
# ind_familia_quilombola_fam       0
# ind_parc_mds_fam                 0
# marc_pbf                         0
# qtde_pessoas                     0
# peso.fam                         0
# dtype: int64

# %%
# identificando colunas com apenas um valor
single_value_columns = [col for col in cadUnicoPB.columns if cadUnicoPB[col].nunique() == 1 | 0]

print(f"Colunas com um único valor: {single_value_columns}")

cadUnicoPB = cadUnicoPB.drop(columns=single_value_columns)
# Out:
# Colunas com um único valor: ['cod_especie_domic_fam', 'cod_banheiro_domic_fam', 'cod_familia_indigena_fam']

# %%
feature_names = cadUnicoPB.columns.tolist()
feature_names.remove('marc_pbf')

# %% [markdown]
# ### Treinando modelo SVM

# %%
# analisando a distribuição da variável alvo (marc_pbf)
target_distribution = cadUnicoPB['marc_pbf'].value_counts(normalize=True) * 100

print(round(target_distribution))
# Out:
# marc_pbf
# 1    65.0
# 0    35.0
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# separar X (features) e y (target)
X = cadUnicoPB.drop('marc_pbf', axis=1)
y = cadUnicoPB['marc_pbf']

# treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# aplicando SMOTE para balancear o conjunto de treino
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

print(y_train_balanced.value_counts())
# Out:
# marc_pbf
# 1    130058
# 0    130058
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# aplicar padronização nas features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_balanced)
X_test_scaled = scaler.transform(X_test)

print("Primeiros dados escalados (padronizados):")
print(X_train_scaled[:5])
# Out:
# Primeiros dados escalados (padronizados):
# [[-0.61648453 -0.57338093  0.61535985  0.884187   -0.52550414 -0.71789997
#   -0.47555839  1.84922055  1.83091414 -0.66749388 -0.19983319 -0.44296607
#   -0.48624828  1.10209049 -0.45432654 -0.21784688  1.23127202  0.05356081
#    3.32044088 -1.17731135  1.69447035]
#  [-1.0974884  -1.53203455 -1.62506541  0.884187   -1.10826096 -0.70134691
#   -0.47555839  0.21565604  0.29883675 -0.66749388 -0.19983319  2.38621136
#    1.88250198 -0.88918577 -0.45432654 -0.21784688 -0.90166122  0.05356081
#   -0.29100429  1.01143881 -0.59637768]
#  [-0.2830315  -1.66999661  0.61535985  0.884187   -0.28499568 -0.69141507
#   -0.47555839 -1.41790847 -1.23324064 -0.66749388 -0.19983319  2.38621136
#    3.06687711 -0.88918577 -0.45432654  3.19727694  1.23127202  0.05356081
#   -0.29100429  0.28185542 -0.59637768]
#  [-1.51184416 -1.39681345 -1.62506541  0.884187   -1.5277283  -0.74107426
#    2.22492746  1.03243829  0.29883675  1.51604203 -0.19983319 -0.44296607
#   -0.48624828  0.10645236  2.10336531 -0.21784688  1.23127202  0.05356081
#   -0.29100429  1.01143881 -0.59637768]
#  [ 0.38366951 -1.32669035  0.61535985 -0.44034183  0.38281645 -0.56892238
#   -0.47555839 -2.23469073 -1.23324064 -0.66749388 -0.19983319 -0.44296607
#   -0.48624828  1.10209049 -0.45432654 -0.21784688 -0.90166122  0.05356081
#   -0.29100429 -1.17731135 -0.59637768]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Inicializando o modelo SVM
svm_model = SVC(kernel='linear', random_state=42, C=1.0, gamma='scale')

# Treinando o modelo com os dados de treino escalados
svm_model.fit(X_train_scaled, y_train_balanced)

# %%
# Previsões no conjunto de teste
y_pred = svm_model.predict(X_test_scaled)

# %%
# Acurácia
accuracy = accuracy_score(y_test, y_pred)
print(f"Acurácia: {accuracy:.2f}")

# Matriz de Confusão
conf_matrix = confusion_matrix(y_test, y_pred)
print("Matriz de Confusão:")
print(conf_matrix)

# Relatório de Classificação
class_report = classification_report(y_test, y_pred, target_names=['Classe 0', 'Classe 1'])
print("Relatório de Classificação:")
print(class_report)
# Out:
# Acurácia: 0.90
# Matriz de Confusão:
# [[22764  4365]
#  [ 1923 34470]]
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#     Classe 0       0.92      0.84      0.88     27129
#     Classe 1       0.89      0.95      0.92     36393
#
#     accuracy                           0.90     63522
#    macro avg       0.90      0.89      0.90     63522
# weighted avg       0.90      0.90      0.90     63522

# %% [markdown]
# ### Extraindo as melhores features

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# Selecionar as 5 melhores features (ajuste o valor de k conforme necessário)
k = 5
selector = SelectKBest(score_func=f_classif, k=k)

# %%
# Ajustar o selector ao conjunto de treino
X_train_selected = selector.fit_transform(X_train_scaled, y_train_balanced)
X_test_selected = selector.transform(X_test_scaled)

# Mostrar as melhores features
selected_features = selector.get_support(indices=True)
print(f"As {k} melhores features (índices):", selected_features)

# Exibir os nomes das melhores features
feature_names_array = np.array(X.columns)  # Convertendo para array
best_feature_names = feature_names_array[selected_features]
print(f"As {k} melhores features (nomes):", best_feature_names)
# Out:
# As 5 melhores features (índices): [ 3  5  7 14 16]
# As 5 melhores features (nomes): ['vlr_renda_media_fam' 'qtd_comodos_domic_fam' 'cod_material_piso_fam'
#  'cod_calcamento_domic_fam' 'qtde_pessoas']

# %%
# Treinando o modelo SVM com as melhores features
svm_model = SVC(kernel='rbf', random_state=42, C=1.0, gamma='scale')
svm_model.fit(X_train_selected, y_train_balanced)
# Out:
# SVC(random_state=42)

# %%
# Previsões com as melhores features
y_pred_selected = svm_model.predict(X_test_selected)

# Avaliar o modelo
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

accuracy = accuracy_score(y_test, y_pred_selected)
print(f"Acurácia com as {k} melhores features: {accuracy:.2f}")

conf_matrix = confusion_matrix(y_test, y_pred_selected)
print("Matriz de Confusão:")
print(conf_matrix)

class_report = classification_report(y_test, y_pred_selected, target_names=['Classe 0', 'Classe 1'])
print("Relatório de Classificação:")
print(class_report)
# Out:
# Acurácia com as 5 melhores features: 0.90
# Matriz de Confusão:
# [[22311  4818]
#  [ 1338 35055]]
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#     Classe 0       0.94      0.82      0.88     27129
#     Classe 1       0.88      0.96      0.92     36393
#
#     accuracy                           0.90     63522
#    macro avg       0.91      0.89      0.90     63522
# weighted avg       0.91      0.90      0.90     63522
